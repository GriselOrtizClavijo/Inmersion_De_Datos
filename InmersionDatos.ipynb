# %% [markdown]
# <a href="https://colab.research.google.com/github/GriselOrtizClavijo/Inmersion_De_Datos/blob/main/InmersionDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AULA 1:**

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Se importa la librería Pandas

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/InmersionDatos/inmuebles_bogota (1).csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %% [markdown]
# .shape = muestra la cantidad de filas, cantidad de columnas

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# Con columns identificamos el nombre de las columnas, y el siguiente paso es como se pueden renombrar.

# %%
columnas = {'Baños':'Banos', 'Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inmuebles.sample(10)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 9303         Casa           Casa en venta en San Patricio             4
# 2962  Apartamento  Apartamento en venta en Nueva Castilla             3
# 2074  Apartamento  Apartamento en venta en Barrios Unidos             3
# 3944  Apartamento   Apartamento en venta en Santa Barbara             1
# 3296  Apartamento        Apartamento en venta en Villemar             3
# 5684  Apartamento        Apartamento en venta en El Batán             3
# 5015  Apartamento        Apartamento en venta en Cedritos             1
# 1265  Apartamento       Apartamento en venta en El Retiro             3
# 3608  Apartamento  Apartamento en venta en Ciudad Salitre             3
# 8909         Casa         Casa en venta en Quinta Camacho             5
#
#       Banos  Area          Barrio                                    UPZ  \
# 9303      4   318    San Patricio  USAQUÉN: Country Club + Santa Bárbara
# 2962      2    61  Nueva Castilla            KENNEDY: Castilla + Bavaria
# 2074      3   166  Barrios Unidos                              Los Andes
# 3944      1    69   Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 3296      2    59        Villemar                               Fontibón
# 5684      3   103        El Batán                            La Alhambra
# 5015      2    55        Cedritos                                Usaquén
# 1265      4   240       El Retiro     CHAPINERO: Chicó Lago + El Refugio
# 3608      2    64  Ciudad Salitre                Ciudad Salitre Oriental
# 8909      5   480  Quinta Camacho     CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 9303  $ 2.200.000.000
# 2962    $ 270.000.000
# 2074    $ 990.000.000
# 3944    $ 425.000.000
# 3296    $ 205.000.000
# 5684    $ 418.000.000
# 5015    $ 340.000.000
# 1265  $ 2.150.000.000
# 3608    $ 466.000.000
# 8909  $ 2.500.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles['Area'][305]
# Out:
# 108

# %% [markdown]
# Con .sample obtenemos una muestra del dataset

# %%
inmuebles.sample(100)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 1634  Apartamento            Apartamento en venta en Fontibón             3
# 9507  Apartamento            Apartamento en venta en Fontibón             3
# 6688  Apartamento                Apartamento en venta en Usme             2
# 9041  Apartamento         Apartamento en venta en Los Rosales             3
# 7270  Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 461          Casa             Casa en venta en Antonio Nariño             5
# 3738  Apartamento             Apartamento en venta en Usaquén             3
# 8414  Apartamento     Apartamento en venta en Chico Reservado             4
# 7605  Apartamento       Apartamento en venta en Santa Barbara             4
# 2288  Apartamento      Apartamento en venta en Barrios Unidos             3
#
#       Banos  Area              Barrio                                    UPZ  \
# 1634      2    75            Fontibón                               Fontibón
# 9507      2    56            Fontibón                               Fontibón
# 6688      1    41                Usme      USME: Alfonso López + Ciudad Usme
# 9041      5   340         Los Rosales     CHAPINERO: Chicó Lago + El Refugio
# 7270      2    68  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# ...     ...   ...                 ...                                    ...
# 461       5   358      Antonio Nariño                               Restrepo
# 3738      2    79             Usaquén                                Usaquén
# 8414      5   226     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 7605      5   261       Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 2288      2    95      Barrios Unidos                              Los Andes
#
#                 Valor
# 1634    $ 327.000.000
# 9507    $ 330.000.000
# 6688    $ 130.000.000
# 9041  $ 3.550.000.000
# 7270    $ 262.000.000
# ...               ...
# 461     $ 850.000.000
# 3738    $ 300.000.000
# 8414  $ 1.950.000.000
# 7605  $ 1.500.000.000
# 2288    $ 259.100.000
#
# [100 rows x 8 columns]

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Desafío
#
# Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.
#
# Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.

# %% [markdown]
# ## **DESAFÍO 1:**

# %%
barrios_agrupados = inmuebles.groupby('Barrio')
promedio_area_barrio = barrios_agrupados['Area'].mean().sort_values(ascending=False)
promedio_area_barrio.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
print(promedio_area_barrio)
# Out:
# Barrio
# Modelia            4316.750000
# Libertador          642.000000
# Bosa Piamonte       400.000000
# La Soledad          378.625000
# Restrepo            336.500000
#                       ...
# La Merced            41.000000
# El Tunal             41.000000
# San Diego            40.666667
# La Macarena          37.000000
# Prado Veraniego      25.000000
# Name: Area, Length: 149, dtype: float64

# %% [markdown]
# SEGUNDA PARTE DE LA ACTIVIDAD

# %% [markdown]
# CONTEO DE BARRIOS

# %%
conteo_barrios = inmuebles['Barrio'].value_counts()
print (conteo_barrios)
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %% [markdown]
# MEDIANA DE INMUEBLES

# %%
inmuebles_ordenados = inmuebles.sort_values('Area')
valor_mediana = inmuebles_ordenados['Area'].median()
fila_mediana = inmuebles.loc[inmuebles['Area'] == valor_mediana]
print(fila_mediana)
# Out:
#              Tipo                               Descripcion  Habitaciones  \
# 9     Apartamento       Apartamento en venta en Bella Suiza             2
# 10    Apartamento       Apartamento en venta en Bella Suiza             2
# 45    Apartamento           Apartamento en venta en Usaquén             2
# 56    Apartamento           Apartamento en venta en Usaquén             2
# 73    Apartamento           Apartamento en venta en Usaquén             2
# ...           ...                                       ...           ...
# 9023  Apartamento              Apartamento en venta en Suba             3
# 9162  Apartamento           Apartamento en venta en Usaquén             2
# 9445  Apartamento          Apartamento en venta en El Batán             3
# 9490         Casa                  Casa en venta en Kennedy            10
# 9505  Apartamento  Apartamento en venta en Colina Campestre             3
#
#       Banos  Area            Barrio                                    UPZ  \
# 9         2    80       Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
# 10        2    80       Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
# 45        2    80           Usaquén                                Usaquén
# 56        2    80           Usaquén                                Usaquén
# 73        2    80           Usaquén                                Usaquén
# ...     ...   ...               ...                                    ...
# 9023      2    80              Suba                                   Suba
# 9162      2    80           Usaquén                                Usaquén
# 9445      2    80          El Batán                            La Alhambra
# 9490      8    80           Kennedy                        Kennedy Central
# 9505      2    80  Colina Campestre                                   Niza
#
#               Valor
# 9     $ 642.000.000
# 10    $ 652.000.000
# 45    $ 349.000.000
# 56    $ 349.000.000
# 73    $ 349.000.000
# ...             ...
# 9023  $ 286.000.000
# 9162  $ 345.000.000
# 9445  $ 451.500.000
# 9490  $ 580.000.000
# 9505  $ 340.000.000
#
# [124 rows x 8 columns]

# %% [markdown]
# AREA MIN Y MAX DE INMUEBLES

# %%
min_area = inmuebles['Area'].min()
max_area = inmuebles['Area'].max()
fila_min_area = inmuebles.loc[inmuebles['Area'] == min_area]
fila_max_area = inmuebles.loc[inmuebles['Area'] == max_area]
print (fila_min_area)
print (fila_max_area)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor
# 8401     2  San Cristobal  Sosiego  $ 180.000.000
#       Tipo               Descripcion  Habitaciones  Banos    Area   Barrio  \
# 7073  Casa  Casa en venta en Modelia             4      3  166243  Modelia
#
#            UPZ          Valor
# 7073  Fontibón  $ 850.000.000

# %% [markdown]
# # **AULA 2:**

# %%
inmuebles.sample(10)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 6572  Apartamento         Apartamento en venta en El Plan             3
# 9448         Casa                Casa en venta en Kennedy             8
# 8629  Apartamento       Apartamento en venta en Chapinero             2
# 2933  Apartamento            Apartamento en venta en Bosa             3
# 5834  Apartamento         Apartamento en venta en Kennedy             3
# 1667  Apartamento            Apartamento en venta en Suba             4
# 2418  Apartamento   Apartamento en venta en Santa Barbara             2
# 4554         Casa           Casa en venta en San Patricio             3
# 7634  Apartamento        Apartamento en venta en El Batán             3
# 4775  Apartamento  Apartamento en venta en Barrios Unidos             2
#
#       Banos  Area          Barrio                                    UPZ  \
# 6572      3   107         El Plan                              El Rincón
# 9448      5   405         Kennedy                        Kennedy Central
# 8629      3   135       Chapinero     CHAPINERO: Pardo Rubio + Chapinero
# 2933      1    47            Bosa                           Bosa Central
# 5834      1    51         Kennedy                        Kennedy Central
# 1667      3   118            Suba                                   Suba
# 2418      2    70   Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 4554      5   331    San Patricio  USAQUÉN: Country Club + Santa Bárbara
# 7634      3    99        El Batán                            La Alhambra
# 4775      1    36  Barrios Unidos                              Los Andes
#
#                 Valor
# 6572    $ 525.000.000
# 9448    $ 750.000.000
# 8629    $ 870.000.000
# 2933    $ 128.000.000
# 5834    $ 169.000.000
# 1667    $ 485.000.000
# 2418    $ 680.000.000
# 4554  $ 2.500.000.000
# 7634    $ 535.000.000
# 4775    $ 100.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# El anterior comando muestra información resumida del dataset

# %%
inmuebles.Valor[0] + inmuebles.Valor[1] + inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
valor = inmuebles.Valor.str.split(expand= True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 2972  Apartamento      Apartamento en venta en Pasadena              2      2
# 526          Casa         Casa en venta en San Cristobal            13      6
# 1750  Apartamento  Apartamento en venta en Santa Barbara             2      3
#
#       Area         Barrio                                    UPZ  \
# 2972    61      Pasadena                                     NaN
# 526    454  San Cristobal                                Sosiego
# 1750   143  Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
#
#                 Valor Moneda         Precio
# 2972    $ 410.000.000      $    410.000.000
# 526     $ 650.000.000      $    650.000.000
# 1750  $ 1.144.253.000      $  1.144.253.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.', '', regex = True)

# %%
inmuebles[['Precio', 'Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles.loc[inmuebles.Banos == 0]
# Out:
#           Tipo                         Descripcion  Habitaciones  Banos  Area  \
# 2910  Edificio  Edificio en venta en Santa Barbara            22      0  1080
# 8193      Casa      Casa en venta en Puente Aranda            15      0   450
# 9451      Casa               Casa en venta en Bosa            10      0   540
#
#              Barrio                                             UPZ  \
# 2910  Santa Barbara           USAQUÉN: Country Club + Santa Bárbara
# 8193  Puente Aranda  PUENTE ARANDA: Zona Industrial + Puente Aranda
# 9451           Bosa                                    Bosa Central
#
#                 Valor Moneda      Precio  Precio_Millon
# 2910  $ 9.200.000.000      $  9200000000        9200.00
# 8193  $ 1.000.000.000      $  1000000000        1000.00
# 9451    $ 800.000.000      $   800000000         800.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

plt.figure(figsize = (10,8))
grafica = sns.histplot(data = inmuebles, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribución de valores de los inmuebles en Bogotá')
plt.xlim((50, 2000))
plt.savefig('/content/drive/MyDrive/InmersionDatos/graficoPrueba.png', format='png')
plt.show()

# %% [markdown]
# Desafío

# %% [markdown]
# 1. Estudiar mejor el histograma, realizando comparaciones entre 3 tipos de inmuebles (Refinar el gráfico: Titulos, etiquetas, aumentar tamaño de labels) Realizar una conclusión de la información con la interpretación del histograma.

# %% [markdown]
# 2. Precio de metro cuadrado por barrio y hacer el gráfico mas adecuado para esta nueva variable.

# %% [markdown]
# ## DEASFÍO 2:

# %% [markdown]
# PUNTO UNO:

# %%
tipos_interes = ['Local', 'Bodega', 'Oficina/Consultorio']
inmuebles_filtrados = inmuebles[inmuebles['Tipo'].isin(tipos_interes)]

plt.figure(figsize = (15,5))
grafica = sns.scatterplot(data = inmuebles_filtrados, x='Precio_Millon', y= 'Tipo', size= 'Area',  hue='Tipo')

conteo = inmuebles_filtrados['Tipo'].value_counts()
ticklabels = [f"{tipo} ({conteo[tipo]})" for tipo in tipos_interes]
grafica.set_yticklabels(ticklabels)

grafica.set_title('Comparación de precios entre locales, bodegas y oficinas')
plt.xlim((20, 7000))
plt.ylim(-1,3)
plt.show()
# Out:
# <ipython-input-51-204010de45e9>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   grafica.set_yticklabels(ticklabels)

# %% [markdown]
# Conclusión: se puede observar  que los locales tienden a ser más caros que las bodegas y las oficinas teniendo en cuenta que se observa menos tamaño del área , y, que las bodegas tienden a ser más grandes que los locales y las oficinas.

# %% [markdown]
# PUNTO DOS:

# %%
inmuebles_barrio = inmuebles.groupby('Barrio')
promedio_m2 = inmuebles_barrio['Precio'].mean() / inmuebles_barrio['Area'].mean()
print (promedio_m2)
# Out:
# Barrio
# Alameda                                                      5979381.44
# Alhambra             12357120814952117281033781402418073030549712357...
# Andes Norte          85812357046338674595983147152375240340198782106...
# Antonio Nariño                                                      inf
# Barrancas            22602089291358026527860374616126719742981609588...
#                                             ...
# Villa Maria          89119940748978831717278600074292294774408467548...
# Villas De Granada    11318897649868765533203903053925263346051168777...
# Villemar             26011560708453760491732157570469131759924636535...
# Zona Franca                                                  2962962.96
# Zona Noroccidental                                                  inf
# Length: 149, dtype: float64

# %%
inmuebles_barrio = inmuebles.groupby('Barrio')
promedio_m2 = inmuebles_barrio['Precio'].mean() / inmuebles_barrio['Area'].mean()

plt.figure(figsize = (20,10))
graficaBarrios = sns.barplot(data = inmuebles, x='Area', y= 'Barrio')

graficaBarrios.set_title('Promedio de Área por Barrio', fontsize = 20)
graficaBarrios.set_xlabel('Area', fontsize = 14)
graficaBarrios.set_ylabel('Barrio', fontsize = 14)
plt.xlim((2, 800))
plt.ylim(0,40)

plt.show()

# %% [markdown]
# # **AULA 3:**

# %%
inmuebles['valor_m2_Millon'] = inmuebles['Precio_Millon'] / inmuebles['Area']
inmuebles.head(10)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
# 5  Apartamento         Apartamento en venta en Bella Suiza             1
# 6  Apartamento         Apartamento en venta en Bella Suiza             1
# 7  Apartamento         Apartamento en venta en Bella Suiza             3
# 8  Apartamento            Apartamento en venta en El Chicó             3
# 9  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
# 5      2    62         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
# 6      2    62         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
# 7      4   212         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
# 8      2   159            El Chicó     CHAPINERO: Chicó Lago + El Refugio
# 9      2    80         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  valor_m2_Millon
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78
# 3    $ 890.000.000      $   890000000         890.00             5.78
# 4    $ 970.000.000      $   970000000         970.00             7.58
# 5    $ 510.000.000      $   510000000         510.00             8.23
# 6    $ 500.000.000      $   500000000         500.00             8.06
# 7  $ 2.350.000.000      $  2350000000        2350.00            11.08
# 8    $ 850.000.000      $   850000000         850.00             5.35
# 9    $ 642.000.000      $   642000000         642.00             8.03

# %%
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_Millon  valor_m2_Millon
# Barrio
# Alameda                     3.00   2.00  97.00         580.00             5.98
# Alhambra                    3.00   2.94 190.41         752.35             4.33
# Andes Norte                 3.00   2.86 124.86         709.57             6.05
# Antonio Nariño              4.31   2.50 163.06         459.22             3.53
# Barrancas                   2.87   2.13  70.20         314.13             4.42
# ...                          ...    ...    ...            ...              ...
# Villa Maria                 4.69   3.69 207.15         402.85             2.04
# Villas De Granada           3.45   2.32  86.59         282.30             3.17
# Villemar                    2.94   2.06  76.89         303.83             3.99
# Zona Franca                 2.00   1.00  54.00         160.00             2.96
# Zona Noroccidental          3.17   2.51 135.79         620.81             4.62
#
# [149 rows x 5 columns]

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     valor_m2_Millon
# Barrio
# Alameda                        5.98
# Alhambra                      73.56
# Andes Norte                   42.35
# Antonio Nariño               169.47
# Barrancas                     66.24
# ...                             ...
# Villa Maria                   26.58
# Villas De Granada             69.71
# Villemar                      71.81
# Zona Franca                    2.96
# Zona Noroccidental          4049.16
#
# [149 rows x 5 columns]

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon'] / datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     valor_m2_Millon  Valor_m2_Barrio
# Barrio
# Alameda                        5.98             5.98
# Alhambra                      73.56             3.95
# Andes Norte                   42.35             5.68
# Antonio Nariño               169.47             2.82
# Barrancas                     66.24             4.47
# ...                             ...              ...
# Villa Maria                   26.58             1.94
# Villas De Granada             69.71             3.26
# Villemar                      71.81             3.95
# Zona Franca                    2.96             2.96
# Zona Noroccidental          4049.16             4.57
#
# [149 rows x 6 columns]

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  valor_m2_Millon  \
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78
# 3    $ 890.000.000      $   890000000         890.00             5.78
# 4    $ 970.000.000      $   970000000         970.00             7.58
#
#    Valor_m2_Barrio
# 0             4.57
# 1             3.40
# 2             8.10
# 3             5.66
# 4             6.29

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %%
datos_barrio.reset_index(inplace = True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      valor_m2_Millon  Valor_m2_Barrio
# 0               5.98             5.98
# 1              73.56             3.95
# 2              42.35             5.68
# 3             169.47             2.82
# 4              66.24             4.47
# ..               ...              ...
# 144            26.58             1.94
# 145            69.71             3.26
# 146            71.81             3.95
# 147             2.96             2.96
# 148          4049.16             4.57
#
# [149 rows x 7 columns]

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      valor_m2_Millon  Valor_m2_Barrio
# 5            2070.61             2.96
# 10           1654.36             2.68
# 22           2853.23             5.03
# 24           2466.03             4.58
# 50           1795.71             2.89
# 63           2127.66             3.38
# 125          2701.88             5.85
# 132          2000.72             4.32
# 138          6334.04             5.66
# 148          4049.16             4.57

# %%
plt.figure(figsize = (10,8))
ax = sns.barplot(x = 'Barrio', y = 'Valor_m2_Barrio', data= datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis = 'x', rotation = 45)

# %%
plt.figure(figsize = (10,8))
ax = sns.boxplot(x = 'Barrio', y = 'valor_m2_Millon', data= inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis = 'x', rotation = 45)
plt.show()

# %%
plt.figure(figsize = (10,8))
ax = sns.boxplot(x = 'Barrio', y = 'valor_m2_Millon', data= inmuebles.query('Barrio in @top_barrios & valor_m2_Millon < 15'))
ax.tick_params(axis = 'x', rotation = 45)
plt.show()

# %%
plt.figure(figsize = (10,8))
ax = sns.boxplot(x = 'Barrio', y = 'Area', data= inmuebles.query('Barrio in @top_barrios & Area<500'))
ax.tick_params(axis = 'x', rotation = 45)
plt.show()

# %%
plt.figure(figsize = (10,8))
ax = sns.boxplot(x = 'Barrio', y = 'Precio_Millon', data= inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis = 'x', rotation = 45)
plt.show()

# %% [markdown]
# ## IMPORTACIÓN DATOS_DANE

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/InmersionDatos/archivos-dane/Identificación (Capítulo A).csv', sep = ';', encoding = 'latin-1')
datos_raw.head(10)
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
# 5  3004351.00    11  11001      1           2.00        Chapinero
# 6  3004352.00    11  11001      1           2.00        Chapinero
# 7  3004353.00    11  11001      1           9.00         Fontibón
# 8  3004354.00    11  11001      1           9.00         Fontibón
# 9  3004355.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 5         816.00      CHAPINERO: Pardo Rubio + Chapinero     11001189
# 6         816.00      CHAPINERO: Pardo Rubio + Chapinero     11001189
# 7         110.00               Ciudad Salitre Occidental     11001115
# 8         110.00               Ciudad Salitre Occidental     11001115
# 9          13.00                              Los Cedros     11001144
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# 1                            Santa Isabel  17,8555889419101
# 2  SANTA FE: Las Nieves + Sagrado Corazón  10,0286103658331
# 3   USAQUÉN: Country Club + Santa Bárbara  28,6502122142802
# 4   USAQUÉN: Country Club + Santa Bárbara  24,4684068319009
# 5      CHAPINERO: Pardo Rubio + Chapinero  18,0625813452102
# 6      CHAPINERO: Pardo Rubio + Chapinero  32,5858068187955
# 7               Ciudad Salitre Occidental  12,1448435131683
# 8               Ciudad Salitre Occidental  17,5760700132957
# 9                              Los Cedros  47,5444485649816

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %%
datos_b = datos_raw = pd.read_csv('/content/drive/MyDrive/InmersionDatos/archivos-dane/Identificación (Capítulo A).csv', sep = ';', encoding = 'latin-1')
datos_c = datos_raw = pd.read_csv('/content/drive/MyDrive/InmersionDatos/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv', sep = ';', encoding = 'latin-1')
datos_e = datos_raw = pd.read_csv('/content/drive/MyDrive/InmersionDatos/archivos-dane/Composición del hogar y demografía (Capítulo E).csv', sep = ';', encoding = 'latin-1')
datos_h = datos_raw = pd.read_csv('/content/drive/MyDrive/InmersionDatos/archivos-dane/Educación (Capítulo H).csv', sep = ';', encoding = 'latin-1')
datos_l = datos_raw = pd.read_csv('/content/drive/MyDrive/InmersionDatos/archivos-dane/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep = ';', encoding = 'latin-1')
datos_k = datos_raw = pd.read_csv('/content/drive/MyDrive/InmersionDatos/archivos-dane/Fuerza de trabajo (Capítulo K).csv', sep = ';', encoding = 'latin-1')

# %%
datos_dane = pd.merge(datos_raw, datos_b, on = 'DIRECTORIO', how = 'left')
datos_dane.shape
# Out:
# (260476, 180)

# %%
datos_dane.shape
# Out:
# (260476, 180)

# %%
datos_dane = pd.merge(datos_dane, datos_c, on = 'DIRECTORIO', how = 'left')

# %%
datos_dane.shape
# Out:
# (263901, 321)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 263901 entries, 0 to 263900
# Columns: 321 entries, DIRECTORIO to FEX_C
# dtypes: float64(198), int64(94), object(29)
# memory usage: 648.3+ MB

# %%
datos_dane.head()
# Out:
#    DIRECTORIO  DIRECTORIO_HOG_x  DIRECTORIO_PER  SECUENCIA_P_x  ORDEN  NPCKP1  \
# 0   166238.00           1662381        16623811              1      1       4
# 1   166238.00           1662381        16623812              1      2       4
# 2   220102.00           2201021        22010214              1      4       3
# 3   220102.00           2201021        22010212              1      2       4
# 4   220102.00           2201021        22010211              1      1       1
#
#    NPCKP2  NPCKP3  NPCKP4  NPCKP5  ...  NHCCP46J  NHCCP46K  NHCCP46L  \
# 0    2.00    2.00    2.00    2.00  ...       NaN       NaN       NaN
# 1    2.00    2.00    2.00    2.00  ...       NaN       NaN       NaN
# 2    2.00    2.00    2.00    2.00  ...       NaN       NaN       NaN
# 3    2.00    2.00    2.00    2.00  ...       NaN       NaN       NaN
# 4     NaN     NaN     NaN     NaN  ...       NaN       NaN       NaN
#
#    NHCCP46M  NHCCP47A  NHCCP47A1  NHCCP47B  NHCCP47B1  NHCCP47C  \
# 0       NaN         1       2.00         2        NaN         2
# 1       NaN         1       2.00         2        NaN         2
# 2       NaN         1       2.00         1       1.00         2
# 3       NaN         1       2.00         1       1.00         2
# 4       NaN         1       2.00         1       1.00         2
#
#               FEX_C
# 0  1,69849246231156
# 1  1,69849246231156
# 2  6,74441212899351
# 3  6,74441212899351
# 4  6,74441212899351
#
# [5 rows x 321 columns]

# %%
datos_raw.head()
# Out:
#    DIRECTORIO  DIRECTORIO_HOG  DIRECTORIO_PER  SECUENCIA_P  ORDEN  NPCKP1  \
# 0   166238.00         1662381        16623811            1      1       4
# 1   166238.00         1662381        16623812            1      2       4
# 2   220102.00         2201021        22010214            1      4       3
# 3   220102.00         2201021        22010212            1      2       4
# 4   220102.00         2201021        22010211            1      1       1
#
#    NPCKP2  NPCKP3  NPCKP4  NPCKP5  ...  DES  FL  FFL  PET_DEFA  OCU_DEFA  \
# 0    2.00    2.00    2.00    2.00  ...    0   0    1         1         0
# 1    2.00    2.00    2.00    2.00  ...    0   0    1         1         0
# 2    2.00    2.00    2.00    2.00  ...    0   0    0         1         0
# 3    2.00    2.00    2.00    2.00  ...    0   0    1         1         0
# 4     NaN     NaN     NaN     NaN  ...    0   1    0         1         1
#
#    DES_DEFA  INI_DEFA  PEA_DEFA  OINFORMAL             FEX_C
# 0         0         1         0        NaN  1,69849246231156
# 1         0         1         0        NaN  1,69849246231156
# 2         0         1         0        NaN  6,74441212899351
# 3         0         1         0        NaN  6,74441212899351
# 4         0         0         1       1.00  6,74441212899351
#
# [5 rows x 170 columns]

# %%
datos_b.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# 1                            Santa Isabel  17,8555889419101
# 2  SANTA FE: Las Nieves + Sagrado Corazón  10,0286103658331
# 3   USAQUÉN: Country Club + Santa Bárbara  28,6502122142802
# 4   USAQUÉN: Country Club + Santa Bárbara  24,4684068319009

# %%
datos_c.head()
# Out:
#    DIRECTORIO  DIRECTORIO_HOG  SECUENCIA_P  NHCCP1 NHCCP2  NHCCP3  NHCCP4A  \
# 0  1165355.00        11653551            1       2  1e+06    1.00     1.00
# 1  1165356.00        11653561            1       3    NaN     NaN      NaN
# 2  1165357.00        11653571            1       1    NaN    1.00     1.00
# 3  1165358.00        11653581            1       1    NaN    1.00     1.00
# 4  1165359.00        11653591            1       1    NaN    1.00     1.00
#
#    NHCCP4B  NHCCP4C  NHCCP4D  ...  NHCCP46J NHCCP46K  NHCCP46L NHCCP46M  \
# 0      NaN      NaN      NaN  ...     30.00    15.00      5.00    60.00
# 1      NaN      NaN      NaN  ...     30.00    15.00      5.00    60.00
# 2      NaN      NaN      NaN  ...     30.00    14.00      5.00    15.00
# 3      NaN      NaN      NaN  ...     30.00    15.00      5.00    60.00
# 4     1.00      NaN      NaN  ...     30.00    15.00      5.00    80.00
#
#    NHCCP47A  NHCCP47A1  NHCCP47B  NHCCP47B1  NHCCP47C             FEX_C
# 0         2        NaN         2        NaN         2  47,6106272985279
# 1         2        NaN         2        NaN         2  51,0122773592785
# 2         2        NaN         2        NaN         2   45,950197007885
# 3         2        NaN         2        NaN         2  63,0174130393852
# 4         2        NaN         2        NaN         2  69,2046521439094
#
# [5 rows x 142 columns]

# %%
datos_e.head()
# Out:
#    DIRECTORIO  DIRECTORIO_HOG  DIRECTORIO_PER  SECUENCIA_P  ORDEN  NPCEP4  \
# 0   166238.00         1662381        16623811            1      1      70
# 1   166238.00         1662381        16623812            1      2      78
# 2   220102.00         2201021        22010211            1      1      45
# 3   220102.00         2201021        22010212            1      2      39
# 4   220102.00         2201021        22010213            1      3      17
#
#    NPCEP_5  NPCEP5  SEXO  NPCEP6  ...  NPCEP22A  NPCEP24  NPCEP24A  NPCEP25  \
# 0        3       2     2       1  ...       NaN        3       NaN     1.00
# 1        3       1     1       2  ...       NaN        3       NaN    99.00
# 2        3       1     1       1  ...      1.00        2       NaN    10.00
# 3        3       2     2       2  ...      1.00        3       NaN     1.00
# 4        2       1     1       3  ...       NaN        1      2.00      NaN
#
#    NPCEP25A  NPCEP27  NPCEP26  NPCEP29  NPCEP29A             FEX_C
# 0      2.00     1.00     1.00      NaN       NaN  1,69849246231156
# 1       NaN     1.00     1.00      NaN       NaN  1,69849246231156
# 2       NaN     1.00     1.00      NaN       NaN  6,74441212899351
# 3      1.00     1.00     1.00      NaN       NaN  6,74441212899351
# 4       NaN      NaN      NaN      NaN       NaN  6,74441212899351
#
# [5 rows x 68 columns]

# %%
datos_h.head()
# Out:
#    DIRECTORIO  DIRECTORIO_HOG  DIRECTORIO_PER  SECUENCIA_P  ORDEN  NPCHP1  \
# 0   166238.00         1662381        16623811            1      1       1
# 1   166238.00         1662381        16623812            1      2       2
# 2   220102.00         2201021        22010211            1      1       1
# 3   220102.00         2201021        22010212            1      2       1
# 4   220102.00         2201021        22010213            1      3       1
#
#    NPCHP2  NPCHP3  NPCHP4  NPCHP4A  ...  NPCHP35D  NPCHP35E  NPCHP35F  \
# 0       2     NaN    3.00     3.00  ...      2.00      2.00      2.00
# 1       2     NaN    1.00      NaN  ...      2.00      2.00      2.00
# 2       2     NaN    3.00     5.00  ...      2.00      2.00      2.00
# 3       2     NaN    3.00     5.00  ...      2.00      2.00      2.00
# 4       1     NaN     NaN      NaN  ...       NaN       NaN       NaN
#
#    NPCHP35I  NPCHP35J  NPCHP35K  NPCHP36  NPCHP36A  NPCHP37             FEX_C
# 0      2.00      2.00      2.00        2       NaN      NaN  1,69849246231156
# 1      2.00      2.00      2.00        2       NaN      NaN  1,69849246231156
# 2      2.00      2.00      2.00        2       NaN      NaN  6,74441212899351
# 3      2.00      2.00      2.00        2       NaN      NaN  6,74441212899351
# 4       NaN       NaN       NaN        2       NaN     3.00  6,74441212899351
#
# [5 rows x 136 columns]

# %%
datos_l.head()
# Out:
#    DIRECTORIO  DIRECTORIO_HOG  SECUENCIA_P  NHCLP1  NHCLP2A  NHCLP2B  NHCLP2C  \
# 0  1165355.00        11653551            1       1        2        2        2
# 1  1165356.00        11653561            1       1        2        2        2
# 2  1165357.00        11653571            1       1        2        2        2
# 3  1165358.00        11653581            1       1        2        2        2
# 4  1165359.00        11653591            1       1        2        2        2
#
#    NHCLP2D  NHCLP2E  NHCLP2AA  ...  NHCLP31AA  NHCLP31AB  NHCLP31AC  \
# 0        2        2         2  ...        NaN        NaN        NaN
# 1        2        2         2  ...        NaN        NaN        NaN
# 2        2        2         2  ...        NaN        NaN        NaN
# 3        2        2         2  ...        NaN        NaN        NaN
# 4        2        2         2  ...       1.00       1.00       2.00
#
#    NHCLP31BA  NHCLP31BB  NHCLP31BC  NHCLP31CA  NHCLP31CB  NHCLP31CC  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4       1.00       1.00       2.00       1.00       1.00       2.00
#
#               FEX_C
# 0  47,6106272985279
# 1  51,0122773592785
# 2   45,950197007885
# 3  63,0174130393852
# 4  69,2046521439094
#
# [5 rows x 179 columns]

# %%
datos_k.head()
# Out:
#    DIRECTORIO  DIRECTORIO_HOG  DIRECTORIO_PER  SECUENCIA_P  ORDEN  NPCKP1  \
# 0   166238.00         1662381        16623811            1      1       4
# 1   166238.00         1662381        16623812            1      2       4
# 2   220102.00         2201021        22010214            1      4       3
# 3   220102.00         2201021        22010212            1      2       4
# 4   220102.00         2201021        22010211            1      1       1
#
#    NPCKP2  NPCKP3  NPCKP4  NPCKP5  ...  DES  FL  FFL  PET_DEFA  OCU_DEFA  \
# 0    2.00    2.00    2.00    2.00  ...    0   0    1         1         0
# 1    2.00    2.00    2.00    2.00  ...    0   0    1         1         0
# 2    2.00    2.00    2.00    2.00  ...    0   0    0         1         0
# 3    2.00    2.00    2.00    2.00  ...    0   0    1         1         0
# 4     NaN     NaN     NaN     NaN  ...    0   1    0         1         1
#
#    DES_DEFA  INI_DEFA  PEA_DEFA  OINFORMAL             FEX_C
# 0         0         1         0        NaN  1,69849246231156
# 1         0         1         0        NaN  1,69849246231156
# 2         0         1         0        NaN  6,74441212899351
# 3         0         1         0        NaN  6,74441212899351
# 4         0         0         1       1.00  6,74441212899351
#
# [5 rows x 170 columns]

# %% [markdown]
# ### ANÁLISIS INICIAL DATOS DANE:
